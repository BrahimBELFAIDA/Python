# %% [markdown]
# <a href="https://colab.research.google.com/github/BrahimBELFAIDA/Python/blob/main/Sales_Data_Analyst_Intern_Interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1 - Python global

# %%
# Imprimer la deuxième lettre
# Answer should be: i
x = "bienvenue"
print(x[1])
# Out:
# i

# %%
from typing import List
# Créer un liste/array avec chaque lettre de x
# Answer should be: ['b', 'i', 'e', 'n', 'v', 'e', 'n', 'u', 'e']
liste=list(x)
print(liste)
# Out:
# ['b', 'i', 'e', 'n', 'v', 'e', 'n', 'u', 'e']

# %%
# Récupérer les 4 derniers éléments de la liste/array créé
# Abswer should be: ['e', 'n', 'u', 'e']
print(liste[-4:])
# Out:
# ['e', 'n', 'u', 'e']

# %%
# Crée un dictionnaire avec des clés allant de 0 à 3 associant les prénoms Pierre, Paul, Jacques, Tom
dict={0:'Pierre',1:'Paul',2:'Jaques',3:'Tom'}
# Answer should be: Tom
print(dict[3])
# Out:
# Tom

# %%
# Créer un array avec les noms par ordre décroissant de clé du dictionnaire
# Answer should be: ['Tom', 'Jacques', 'Paul', 'Pierre']
sorted_keys_desc = sorted(dict.keys(), reverse=True)
liste_noms=[]
for i in sorted_keys_desc:
  liste_noms.append(dict[i])
print(liste_noms)
# Out:
# ['Tom', 'Jaques', 'Paul', 'Pierre']

# %%
# Quelle différence entre une serie et un dataframe

# %% [markdown]
# # Part 2 - Pandas

# %%
import pandas as pd

# Telecharge les datasets
movie_title_url = 'https://dl.dropboxusercontent.com/scl/fi/31airtb7y8al0d2atbmuq/movie_title.csv?rlkey=zk55g4yh8aumzikt29gw96cea&st=mcmz8u74&dl=0'
ratings_url = 'https://dl.dropboxusercontent.com/scl/fi/fxj5ptkf6py81j4vo5r2e/ratings.csv?rlkey=cqy0u8ymbqrk821ffomrf57rj&st=larahgwe&dl=0'

# Charge les datasets
movie_title = pd.read_csv(movie_title_url)
ratings = pd.read_csv(ratings_url)

# Remove useless idx column
movie_title.drop(columns='Unnamed: 0', inplace=True)
ratings.drop(columns='Unnamed: 0', inplace=True)

# %% [markdown]
# ## Dataset description
# # movie_title
# * **tconst (string)** - alphanumeric unique identifier of the title
# * **titleType (string)** – the type/format of the * title (e.g. movie, short, tvseries, tvepisode, video, etc)
# * **primaryTitle (string)** – the more popular title / the title used by the filmmakers on promotional materials at the point of release
# * **originalTitle (string)** - original title, in the original language
# * **isAdult (boolean)** - 0: non-adult title; 1: adult title
# * **startYear (YYYY)** – represents the release year of a title. In the case of TV Series, it is the series start year
# * **endYear (YYYY)** – TV Series end year. ‘\N’ for all other title types
# runtimeMinutes – primary runtime of the title, in minutes
# * **genres (string array)** – includes up to three genres associated with the title
#
# ### ratings
# * **tconst (string)** - alphanumeric unique identifier of the title
# * **averageRating** – weighted average of all the individual user ratings
# * **numVotes** - number of votes the title has received

# %%
movie_title.head(5)
# Out:
#       tconst titleType                   primaryTitle  \
# 0  tt0000009     movie                     Miss Jerry
# 1  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 2  tt0000502     movie                       Bohemios
# 3  tt0000574     movie    The Story of the Kelly Gang
# 4  tt0000591     movie               The Prodigal Son
#
#                    originalTitle  startYear  endYear  runtimeMinutes  \
# 0                     Miss Jerry     1894.0      NaN            45.0
# 1  The Corbett-Fitzsimmons Fight     1897.0      NaN           100.0
# 2                       Bohemios     1905.0      NaN           100.0
# 3    The Story of the Kelly Gang     1906.0      NaN            70.0
# 4              L'enfant prodigue     1907.0      NaN            90.0
#
#                        genres
# 0                     Romance
# 1      Documentary,News,Sport
# 2                         NaN
# 3  Action,Adventure,Biography
# 4                       Drama

# %%
ratings.head(5)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2059
# 1  tt0000002            5.6       278
# 2  tt0000003            6.5      2028
# 3  tt0000004            5.4       179
# 4  tt0000005            6.2      2795

# %%
####################################################################################################
# Afficher nombre de films n'ayant pas de genre
print(movie_title['genres'].isnull().sum())
# Quel est le genre de film le plus produit?
print(movie_title['genres'].value_counts().head(1))
# Donner la note moyenne par année (tout genre confondu)
movie_title.merge(ratings, how='left', on=['tconst']).groupby('startYear')['averageRating'].mean()
# Donner le nombre de films qui ont un titre principal et original différent par genre

# Donner la durée moyenne par année et par genre des films. Quelle tendence semble en découler?
####################################################################################################
# Out:
# 74273
# genres
# Drama    126389
# Name: count, dtype: int64
# startYear
# 1894.0    5.4
# 1896.0    4.0
# 1897.0    4.8
# 1898.0    3.6
# 1899.0    3.6
#          ...
# 2027.0    NaN
# 2028.0    NaN
# 2029.0    NaN
# 2030.0    NaN
# 2031.0    NaN
# Name: averageRating, Length: 137, dtype: float64
